# %%
from copy import deepcopy
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from matplotlib import pyplot as plt

# %%
center_1 = np.array([1,1])
center_2 = np.array([5,5])
center_3 = np.array([8,1])

# Generate random data and center it to the three centers
data_1 = np.random.randn(200, 2) + center_1
data_2 = np.random.randn(200,2) + center_2
data_3 = np.random.randn(200,2) + center_3

data = np.concatenate((data_1, data_2, data_3), axis = 0)
print(data[i])
plt.scatter(data[:,0], data[:,1], s=7)
# Out:
# [ 1.21926277 -0.49418031]

# %%
# Number of clusters
k = 3
# Number of training data
n = data.shape[0]
# Number of features in the data
c = data.shape[1]

# Generate random centers, here we use sigma and mean to ensure it represent the whole data
mean = np.mean(data, axis = 0)
std = np.std(data, axis = 0)
centers = np.random.randn(k,c)*std + mean

# Plot the data and the centers generated as random
plt.scatter(data[:,0], data[:,1], s=7)
plt.scatter(centers[:,0], centers[:,1], marker='*', c='g', s=150)

# %%
def euc_distance(point  , centers ,k):
  #  print(centers.shape[0])
    distance = None
    distance = np.array(np.sqrt((point[0]  - centers[:, 0])**2 + (point[1]  - centers[:, 1])**2 ))
    return distance

# %%
error = 1
new_centers = deepcopy(centers)

distances = np.zeros((1,3))
old_centers = deepcopy(centers)
new_cluster = np.zeros(data.shape[0])
v= None
old_cluster = deepcopy(new_cluster)
cluster_assignment =[]
while error!=0:
    for i in range(data.shape[0]):
        distances = euc_distance(data[i] , new_centers  ,3)
        cluster_index = np.argmin(distances , axis = 0 )
        new_cluster[i] = cluster_index
        
       
    
    #new centroid
    #print(new_cluster)
    for i in range(k):
        for j in range(new_cluster.shape[0]):
            if i == new_cluster[j]:
                cluster_assignment.append(j)
       # print(cluster_assignment)
        
        new_centers[i , 0] = np.mean([data[z , 0] for z in cluster_assignment ])
        new_centers[i , 1] = np.mean([data[z , 1] for z in cluster_assignment ])
                
       # print(new_centers)
        cluster_assignment = []
    print('lol')
    error = np.sqrt((new_centers[:,0]- old_centers[:,0])**2 +(new_centers[:,1]- old_centers[:,1])**2).all()
    old_centers = deepcopy(new_centers)
    
                
print(new_cluster.shape)
# Out:
# lol
# lol
# lol
# lol
# lol
# lol
# (600,)

# %%
plt.scatter(data[:,0], data[:,1], s=7)
plt.scatter(new_centers[:,0], new_centers[:,1], marker='*', c='g', s=150)

# %%
x = np.array([[1,2,3,7] , [2,3,4,5]])
x[1,2]
# Out:
# 4
